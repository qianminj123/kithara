# %% [markdown]
# # Example Notebook: SFT with LORA on Gemma2-2b
#
# ## **Before You Begin: Connect to a TPU runtime. The free v2-8 TPU runtime will work for this example.**

# %% [markdown]
# # Install Kithara

# %%
# Install Kithara
# !pip install kithara[tpu] -f https://storage.googleapis.com/jax-releases/libtpu_releases.html --extra-index-url https://download.pytorch.org/whl/cpu

# Colab specific set up
# !pip uninstall torchvision -y && pip install torchvision==0.19.0 --index-url https://download.pytorch.org/whl/cpu
# !pip install flask==2.1.3

# %% [markdown]
# # Login to HuggingFace with your access token

# %%
import os
os.environ["KERAS_BACKEND"] = "jax"
import keras
import jax
from typing import Tuple
import ray
from ray.data import Dataset
from typing import Union, Optional, List
from kithara import KerasHubModel, MaxTextModel, Dataloader, Trainer, PredefinedShardingStrategy, SFTDataset,PredefinedShardingStrategy
from transformers import AutoTokenizer
# Out:
# Installing MaxText... This should only happen once when Kithara is first initiated.
# MaxText installed successfully
# JAX compilation cached at /root/.keras/jax_cache
#        '==='
#         |||
#      '- ||| -'
#     /  |||||  \   Kithara. Platform: Linux. JAX: 0.5.2
#    |   (|||)   |  Hardware: TPU v2. Device count: 8.
#    |   |◕‿◕|   |  HBM Per Device: 7.48 GB. Total HBM Memory: 59.86 GB
#     \  |||||  /   Free Apache license: http://github.com/ai-hypercomputer/kithara
#      --|===|--

# %%
from huggingface_hub import login
import os
hf_token = ""
login(token=hf_token, add_to_git_credential=False)

# %% [markdown]
# # Create Model

# %%
model = KerasHubModel.from_preset(
    "hf://google/gemma-2-2b",
    precision="mixed_bfloat16",
    lora_rank=4, # Specify LoRA Rank here
)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/818 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/24.2k [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/481M [00:00<?, ?B/s]

# %% [markdown]
# # Create Data

# %%
# Create Toy Data
dataset_items = [
    {
        "prompt": "What is your name?",
        "answer": "My name is Kithara",
    }
    for _ in range(1000)
]
dataset = ray.data.from_items(dataset_items)
train_ds, eval_ds = dataset.train_test_split(test_size=500)

# Create Datasets
train_dataset = SFTDataset(
    train_ds,
    tokenizer_handle="hf://google/gemma-2-2b",
    max_seq_len=1024,
)

eval_dataset = SFTDataset(
    eval_ds,
    tokenizer_handle="hf://google/gemma-2-2b",
    max_seq_len=1024,
)

# Create Dataloders
train_dataloader = Dataloader(
    train_dataset,
    per_device_batch_size=1
)

eval_dataloader = Dataloader(
    eval_dataset,
    per_device_batch_size=1
)

# %% [markdown]
# ##Initialize trainer and start training

# %%
optimizer = keras.optimizers.AdamW(
    learning_rate=2e-4,
    weight_decay=0.01
)

trainer = Trainer(
    model=model,
    optimizer=optimizer,
    train_dataloader=train_dataloader,
    eval_dataloader=eval_dataloader,
    steps=200, # You can also use epochs instead of steps
    eval_steps_interval=50,
    max_eval_samples=50,
    log_steps_interval=10,
)

trainer.train()
# Out:
#        '==='
#         |||
#      '- ||| -'
#     /  |||||  \   Kithara | Device Count = 8
#    |   (|||)   |  Steps = 200 | Batch size per device = 1
#    |   |◕‿◕|   |  Total batch size = 8 | Total parameters = 9.750(GB)
#     \  |||||  /   Trainable parameters = 0.011(GB) (0.11%) | Non-trainable = 9.739(GB)
#      --|===|--
# model <kithara.model.kerashub.keras_hub_model.KerasHubModel object at 0x7f8a4c02d150>
# optimizer <keras.src.optimizers.adamw.AdamW object at 0x7f92901e89d0>
# train_dataloader <kithara.dataset.dataloader.Dataloader object at 0x7f88d4180a50>
# eval_dataloader <kithara.dataset.dataloader.Dataloader object at 0x7f929029af10>
# steps 200
# epochs None
# tensorboard_dir None
# step_count 0
# epoch_count 0
# eval_steps_interval 10
# eval_epochs_interval None
# max_eval_samples 50
# log_steps_interval 10
# global_batch_size 8
# profiler None
# checkpointer None
# callbacks <keras.src.callbacks.callback_list.CallbackList object at 0x7f88d41a3310>
# train_step <PjitFunction of <bound method Trainer._train_step of <kithara.trainer.trainer.Trainer object at 0x7f8a401fbb90>>>
# eval_step <PjitFunction of <bound method Trainer._eval_step of <kithara.trainer.trainer.Trainer object at 0x7f8a401fbb90>>>
# data_sharding NamedSharding(mesh=Mesh('Axis.FSDP': 8), spec=PartitionSpec(<Axis.FSDP: 'fsdp'>, None), memory_kind=device)
# device_count 8
# WARNING: Potential memory leakage. HBM usage is 10028.782 MB but model and optimizer are only 10006.438 MB in size. Total memory available is 61295.875 MB, if you run into errors, check if your memory usage is close to the limit, and either reduce your per-device batch size or sequence length.
# -> Start training...
# The first training step will be slow due to JAX compilation.
# {'step': 1, 'loss': 5.299, 'step_time': 74.21, 'epoch': 1, 'tokens_per_second_per_device': 13.8, 'tokens_per_second': 110.4, 'samples_per_second': 0.11, 'train_steps_per_second': 0.01, 'samples_seen': 8, 'learning_rate': Array(0.0002, dtype=float32)}
# {'step': 10, 'loss': 3.672, 'step_time': 0.77, 'epoch': 1, 'tokens_per_second_per_device': 1327.9, 'tokens_per_second': 10623.5, 'samples_per_second': 10.37, 'train_steps_per_second': 1.3, 'samples_seen': 80, 'learning_rate': Array(0.0002, dtype=float32)}
# Eval loss after 10 training steps:  3.4314976
# {'step': 20, 'loss': 1.676, 'step_time': 0.77, 'epoch': 1, 'tokens_per_second_per_device': 1328.5, 'tokens_per_second': 10627.6, 'samples_per_second': 10.38, 'train_steps_per_second': 1.3, 'samples_seen': 160, 'learning_rate': Array(0.0002, dtype=float32)}
# Eval loss after 20 training steps:  1.5059867
# {'step': 30, 'loss': 0.662, 'step_time': 0.77, 'epoch': 1, 'tokens_per_second_per_device': 1327.3, 'tokens_per_second': 10618.7, 'samples_per_second': 10.37, 'train_steps_per_second': 1.3, 'samples_seen': 240, 'learning_rate': Array(0.0002, dtype=float32)}
# Eval loss after 30 training steps:  0.60598874
# {'step': 40, 'loss': 0.306, 'step_time': 0.77, 'epoch': 1, 'tokens_per_second_per_device': 1329.6, 'tokens_per_second': 10637.2, 'samples_per_second': 10.39, 'train_steps_per_second': 1.3, 'samples_seen': 320, 'learning_rate': Array(0.0002, dtype=float32)}
# Eval loss after 40 training steps:  0.26995385
# {'step': 50, 'loss': 0.034, 'step_time': 0.77, 'epoch': 1, 'tokens_per_second_per_device': 1329.2, 'tokens_per_second': 10633.7, 'samples_per_second': 10.38, 'train_steps_per_second': 1.3, 'samples_seen': 400, 'learning_rate': Array(0.0002, dtype=float32)}
# Eval loss after 50 training steps:  0.023773331
# {'step': 60, 'loss': 0.002, 'step_time': 0.77, 'epoch': 1, 'tokens_per_second_per_device': 1327.7, 'tokens_per_second': 10621.6, 'samples_per_second': 10.37, 'train_steps_per_second': 1.3, 'samples_seen': 480, 'learning_rate': Array(0.0002, dtype=float32)}
# Eval loss after 60 training steps:  0.0016650471
# Train epoch 1 (epoch may be incompete) loss : 1.4112746715545654
# {'step': 70, 'loss': 0.001, 'step_time': 0.77, 'epoch': 2, 'tokens_per_second_per_device': 1328.3, 'tokens_per_second': 10626.5, 'samples_per_second': 10.38, 'train_steps_per_second': 1.3, 'samples_seen': 560, 'learning_rate': Array(0.0002, dtype=float32)}
# Eval loss after 70 training steps:  0.0007754094
# {'step': 80, 'loss': 0.0, 'step_time': 0.77, 'epoch': 2, 'tokens_per_second_per_device': 1327.7, 'tokens_per_second': 10621.8, 'samples_per_second': 10.37, 'train_steps_per_second': 1.3, 'samples_seen': 640, 'learning_rate': Array(0.0002, dtype=float32)}
# Eval loss after 80 training steps:  0.00040549942
# {'step': 90, 'loss': 0.0, 'step_time': 0.77, 'epoch': 2, 'tokens_per_second_per_device': 1328.8, 'tokens_per_second': 10630.5, 'samples_per_second': 10.38, 'train_steps_per_second': 1.3, 'samples_seen': 720, 'learning_rate': Array(0.0002, dtype=float32)}
# Eval loss after 90 training steps:  0.00027659338
# {'step': 100, 'loss': 0.0, 'step_time': 0.77, 'epoch': 2, 'tokens_per_second_per_device': 1328.4, 'tokens_per_second': 10627.1, 'samples_per_second': 10.38, 'train_steps_per_second': 1.3, 'samples_seen': 800, 'learning_rate': Array(0.0002, dtype=float32)}
# Eval loss after 100 training steps:  0.0002126785
# {'step': 110, 'loss': 0.0, 'step_time': 0.77, 'epoch': 2, 'tokens_per_second_per_device': 1328.3, 'tokens_per_second': 10626.7, 'samples_per_second': 10.38, 'train_steps_per_second': 1.3, 'samples_seen': 880, 'learning_rate': Array(0.0002, dtype=float32)}
# Eval loss after 110 training steps:  0.00016530466
# {'step': 120, 'loss': 0.0, 'step_time': 0.77, 'epoch': 2, 'tokens_per_second_per_device': 1328.2, 'tokens_per_second': 10625.6, 'samples_per_second': 10.38, 'train_steps_per_second': 1.3, 'samples_seen': 960, 'learning_rate': Array(0.0002, dtype=float32)}
# Eval loss after 120 training steps:  0.00014728865
# Train epoch 2 (epoch may be incompete) loss : 0.0003608453553169966
# {'step': 130, 'loss': 0.0, 'step_time': 0.77, 'epoch': 3, 'tokens_per_second_per_device': 1328.0, 'tokens_per_second': 10623.9, 'samples_per_second': 10.37, 'train_steps_per_second': 1.3, 'samples_seen': 1040, 'learning_rate': Array(0.0002, dtype=float32)}
# Eval loss after 130 training steps:  0.00013187344
# {'step': 140, 'loss': 0.0, 'step_time': 0.77, 'epoch': 3, 'tokens_per_second_per_device': 1327.6, 'tokens_per_second': 10620.4, 'samples_per_second': 10.37, 'train_steps_per_second': 1.3, 'samples_seen': 1120, 'learning_rate': Array(0.0002, dtype=float32)}
# Eval loss after 140 training steps:  0.00011049687
# {'step': 150, 'loss': 0.0, 'step_time': 0.77, 'epoch': 3, 'tokens_per_second_per_device': 1330.2, 'tokens_per_second': 10641.7, 'samples_per_second': 10.39, 'train_steps_per_second': 1.3, 'samples_seen': 1200, 'learning_rate': Array(0.0002, dtype=float32)}
# Eval loss after 150 training steps:  0.00010659603
# {'step': 160, 'loss': 0.0, 'step_time': 0.77, 'epoch': 3, 'tokens_per_second_per_device': 1327.9, 'tokens_per_second': 10623.1, 'samples_per_second': 10.37, 'train_steps_per_second': 1.3, 'samples_seen': 1280, 'learning_rate': Array(0.0002, dtype=float32)}
# Eval loss after 160 training steps:  9.599572e-05
# {'step': 170, 'loss': 0.0, 'step_time': 0.77, 'epoch': 3, 'tokens_per_second_per_device': 1328.7, 'tokens_per_second': 10629.3, 'samples_per_second': 10.38, 'train_steps_per_second': 1.3, 'samples_seen': 1360, 'learning_rate': Array(0.0002, dtype=float32)}
# Eval loss after 170 training steps:  8.769009e-05
# {'step': 180, 'loss': 0.0, 'step_time': 0.77, 'epoch': 3, 'tokens_per_second_per_device': 1329.8, 'tokens_per_second': 10638.8, 'samples_per_second': 10.39, 'train_steps_per_second': 1.3, 'samples_seen': 1440, 'learning_rate': Array(0.0002, dtype=float32)}
# Eval loss after 180 training steps:  8.1821454e-05
# Train epoch 3 (epoch may be incompete) loss : 0.00010304938768967986
# {'step': 190, 'loss': 0.0, 'step_time': 0.77, 'epoch': 4, 'tokens_per_second_per_device': 1328.9, 'tokens_per_second': 10631.0, 'samples_per_second': 10.38, 'train_steps_per_second': 1.3, 'samples_seen': 1520, 'learning_rate': Array(0.0002, dtype=float32)}
# Eval loss after 190 training steps:  7.413632e-05
# {'step': 200, 'loss': 0.0, 'step_time': 0.77, 'epoch': 4, 'tokens_per_second_per_device': 1328.1, 'tokens_per_second': 10625.1, 'samples_per_second': 10.38, 'train_steps_per_second': 1.3, 'samples_seen': 1600, 'learning_rate': Array(0.0002, dtype=float32)}
# Eval loss after 200 training steps:  7.266797e-05
# Train epoch 4 (epoch may be incompete) loss : 7.409889076370746e-05

# %% [markdown]
# ## Prompt the model

# %%
pred = model.generate(
    "What is your name?",
    max_length=30,
    tokenizer_handle="hf://google/gemma-2-2b",
    return_decoded=True
)
print("Tuned model generates:", pred)
# Out:
# Tuned model generates: ['What is your name?My name is Kithara']
